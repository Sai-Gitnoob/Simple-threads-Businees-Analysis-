# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("D:\Coding\College IITJ\BDA\Capstone\Datas\Purchase_Information(cleaned).csv")
print(df.head())
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\admin\AppData\Local\Temp\ipykernel_11756\2956242254.py:6: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_csv("D:\Coding\College IITJ\BDA\Capstone\Datas\Purchase_Information(cleaned).csv")
#   Transaction Date Transaction ID Customer ID  Product ID Discount Code  \
# 0       2025-01-05          TR101      AB1234        1001        ABCDEF
# 1       2025-01-05          TR101      AB1234        1011        ABCDEF
# 2       2025-01-06          TR102      CD5678        1002           NaN
# 3       2025-01-10          TR103      EF9012        1004        GHIJKL
# 4       2025-01-10          TR103      EF9012        1005        GHIJKL
#
#    Amount
# 0   340.0
# 1   680.0
# 2   400.0
# 3   450.0
# 4   450.0

# %%
df["Discount Used"] = df["Discount Code"].notnull().astype(int)

corr = df[["Discount Used", "Amount"]].corr()
print("Correlation matrix:\n", corr)
# Out:
# Correlation matrix:
#                 Discount Used    Amount
# Discount Used       1.000000  0.019422
# Amount              0.019422  1.000000

# %%
plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0, fmt=".2f")
plt.title("Correlation: Discount Usage vs Amount Spent")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x="Discount Used", y="Amount", data=df)
plt.xticks([0, 1], ["No Discount", "Used Discount"])
plt.title("Spending vs Discount Usage")
plt.ylabel("Amount Spent")
plt.show()
